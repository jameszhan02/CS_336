# %%
from dotenv import load_dotenv
import anthropic

load_dotenv()  

client = anthropic.Anthropic()

# %%
messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "Hi, how are you?"
                }
            ]
        }
    ]
# message = client.messages.create(
#     model="deepseek-v4-pro",
#     max_tokens=1024,
#     system="You are a helpful assistant.",
#     messages=[
#         {
#             "role": "user",
#             "content": [
#                 {
#                     "type": "text",
#                     "text": "Hi, how are you?"
#                 }
#             ]
#         }
#     ]
# )
# print(message.content)


response = client.messages.create(
    model="deepseek-v4-pro",
    max_tokens=1024,
    tools=tools,
)
# Out:
# [ThinkingBlock(signature='fbbfbc8a-e892-4d10-ba49-d6d42faa036a', thinking='We are asked: "Hi, how are you?" This is a simple greeting. I need to respond politely. The user is likely just starting a conversation. I should reply in a friendly manner, ask how they are, and offer assistance. Since I\'m an AI, I can mention that I\'m here to help. Keep it warm and concise.', type='thinking'), TextBlock(citations=None, text="Hello! I'm doing well, thank you. How are you doing today? 😊 I'm here to help if you need anything.", type='text')]
